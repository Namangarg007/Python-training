# %%
from gensim.models import Word2Vec
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
with open("speech") as f:
    text = f.read()

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/naman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sents = sent_tokenize(text)

# %%
sents_words = [word_tokenize(sent.lower()) for sent in sents]

# %%
model = Word2Vec(sents_words)
# Out:
# /home/naman/.local/lib/python3.8/site-packages/gensim/models/base_any2vec.py:742: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   warnings.warn(

# %%
model.wv.vocab
# Out:
# {'26': <gensim.models.keyedvectors.Vocab at 0x7f4ccc498b80>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7f4ccc498eb0>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x7f4c88436ee0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f4c87969d30>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x7f4c87969850>,
#  'niti': <gensim.models.keyedvectors.Vocab at 0x7f4c87969880>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f4c87969e20>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f4c87969fa0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f4c87969b80>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f4c879699a0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f4c87969820>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39040>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f390a0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39100>,
#  'depend': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39160>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f4c85f391c0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39220>,
#  'quantity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39280>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f4c85f392e0>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39340>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f4c85f393a0>,
#  'labour': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39400>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39460>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f4c85f394c0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39520>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39580>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f4c85f395e0>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39640>,
#  'depends': <gensim.models.keyedvectors.Vocab at 0x7f4c85f396a0>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39700>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39760>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f4c85f397c0>,
#  'institutions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39820>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39880>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f4c85f398e0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39940>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f4c85f399a0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39a00>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39a60>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39ac0>,
#  'namely': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39b20>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39b50>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39bb0>,
#  'transforming': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39c10>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39c70>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39cd0>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39d30>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39d90>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39df0>,
#  'tank': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39e50>,
#  'guide': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39eb0>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39f10>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39f70>,
#  'transformation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f39fd0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a070>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a0d0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a130>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a190>,
#  'mainstream': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a1f0>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a250>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a2b0>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a310>,
#  'policies': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a370>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a3d0>,
#  'collaboration': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a430>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a490>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a4f0>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a550>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a5b0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a610>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a670>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a6d0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a730>,
#  'practitioners': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a790>,
#  'instrument': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a7f0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a850>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a8b0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a910>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a970>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3a9d0>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3aa30>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3aa90>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3aaf0>,
#  'administrative': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ab50>,
#  'tradition': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3abb0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ac10>,
#  'indigenous': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ac70>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3acd0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ad30>,
#  'served': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ad90>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3adf0>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ae50>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3aeb0>,
#  'ways': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3af10>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3af70>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3afd0>,
#  'democracy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b070>,
#  'federalism': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b0d0>,
#  'unity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b130>,
#  'integrity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b190>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b1f0>,
#  'glorious': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b250>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b2b0>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b310>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b370>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b3d0>,
#  'achievements': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b430>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b490>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b4f0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b550>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b5b0>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b610>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b670>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b6d0>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b730>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b790>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b7f0>,
#  'reasons': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b850>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b8b0>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b910>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b970>,
#  'experiences': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3b9d0>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ba30>,
#  'strengths': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ba90>,
#  'thirty': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3baf0>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bb50>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bbb0>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bc10>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bc70>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bcd0>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bd30>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bd90>,
#  'solutions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bdf0>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3be50>,
#  'inter': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3beb0>,
#  'dependent': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bf10>,
#  'connected': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bf70>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3bfd0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d070>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d0d0>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d130>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d190>,
#  'isolation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d1f0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d250>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d2b0>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d310>,
#  'standards': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d370>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d3d0>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d430>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d490>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d4f0>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d550>,
#  'younger': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d5b0>,
#  'generation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d610>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d670>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d6d0>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d730>,
#  'differently': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d790>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d7f0>,
#  'rooted': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d850>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d8b0>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d910>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d970>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3d9d0>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3da30>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3da90>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3daf0>,
#  'elders': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3db50>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dbb0>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dc10>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dc70>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dcd0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dd30>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dd90>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ddf0>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3de50>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3deb0>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3df10>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3df70>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3dfd0>,
#  'challenge': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e070>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e0d0>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e130>,
#  'expectations': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e190>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e1f0>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e250>,
#  'mere': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e2b0>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e310>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e370>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e3d0>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e430>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e490>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e4f0>,
#  'rapid': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e550>,
#  'evolution': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e5b0>,
#  '•': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e610>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e670>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e6d0>,
#  'governance': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e730>,
#  'mindset': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e790>,
#  'transformative': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e7f0>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e850>,
#  'eliminate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e8b0>,
#  'unnecessary': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e910>,
#  'procedures': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e970>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3e9d0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ea30>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ea90>,
#  'adopt': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3eaf0>,
#  'march': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3eb50>,
#  'twenty': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ebb0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ec10>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ec70>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ecd0>,
#  'fundamental': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ed30>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ed90>,
#  'mindsets': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3edf0>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ee50>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3eeb0>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ef10>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3ef70>,
#  'democratic': <gensim.models.keyedvectors.Vocab at 0x7f4c85f3efd0>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40070>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f4c85f400d0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40130>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40190>,
#  'efforts': <gensim.models.keyedvectors.Vocab at 0x7f4c85f401f0>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40250>,
#  'ourselves': <gensim.models.keyedvectors.Vocab at 0x7f4c85f402b0>,
#  'individuals': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40310>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40370>,
#  'absorb': <gensim.models.keyedvectors.Vocab at 0x7f4c85f403d0>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40430>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40490>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x7f4c85f404f0>,
#  'articles': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40550>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f4c85f405b0>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40610>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40670>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f4c85f406d0>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40730>,
#  'collectively': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40790>,
#  'confined': <gensim.models.keyedvectors.Vocab at 0x7f4c85f407f0>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40850>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7f4c85f408b0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40910>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40970>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f4c85f409d0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40a30>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40a90>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40af0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40b50>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40bb0>,
#  'capacity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40c10>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40c70>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40cd0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40d30>,
#  'collective': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40d90>,
#  'convert': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40df0>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40e50>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40eb0>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40f10>,
#  'opening': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40f70>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f4c85f40fd0>,
#  'perspectives': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42070>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7f4c85f420d0>,
#  'requires': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42130>,
#  'concerted': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42190>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x7f4c85f421f0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42250>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f4c85f422b0>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42310>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42370>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x7f4c85f423d0>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42430>,
#  'personally': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42490>,
#  'participated': <gensim.models.keyedvectors.Vocab at 0x7f4c85f424f0>,
#  'sessions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42550>,
#  'bankers': <gensim.models.keyedvectors.Vocab at 0x7f4c85f425b0>,
#  'police': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42610>,
#  'officers': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42670>,
#  'secretaries': <gensim.models.keyedvectors.Vocab at 0x7f4c85f426d0>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42730>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42790>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7f4c85f427f0>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42850>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f428b0>,
#  'tap': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42910>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42970>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f4c85f429d0>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42a30>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42a90>,
#  'indians': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42af0>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42b50>,
#  'elsewhere': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42bb0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42c10>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42c70>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42cd0>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42d30>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42d90>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42df0>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42e50>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42eb0>,
#  'directions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42f10>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42f70>,
#  'lecture': <gensim.models.keyedvectors.Vocab at 0x7f4c85f42fd0>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44070>,
#  'attend': <gensim.models.keyedvectors.Vocab at 0x7f4c85f440d0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44130>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44190>,
#  'draw': <gensim.models.keyedvectors.Vocab at 0x7f4c85f441f0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44250>,
#  'wisdom': <gensim.models.keyedvectors.Vocab at 0x7f4c85f442b0>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44310>,
#  'eminent': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44370>,
#  'persons': <gensim.models.keyedvectors.Vocab at 0x7f4c85f443d0>,
#  'influenced': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44430>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44490>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f4c85f444f0>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44550>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f4c85f445b0>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44610>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44670>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f4c85f446d0>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44730>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44790>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7f4c85f447f0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44850>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f448b0>,
#  'frank': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44910>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44970>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7f4c85f449d0>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44a30>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44a90>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44af0>,
#  'names': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44b50>,
#  'conduct': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44bb0>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44c10>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44c70>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44cd0>,
#  'participants': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44d30>,
#  'emerge': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44d90>,
#  'session': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44df0>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44e50>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44eb0>,
#  'relevant': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44f10>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44f70>,
#  'wherever': <gensim.models.keyedvectors.Vocab at 0x7f4c85f44fd0>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46070>,
#  'ministers': <gensim.models.keyedvectors.Vocab at 0x7f4c85f460d0>,
#  'participate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46130>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46190>,
#  'transformed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f461f0>,
#  'singapore': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46250>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x7f4c85f462b0>,
#  'shri': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46310>,
#  'shanmugaratnam': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46370>,
#  'deputy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f463d0>,
#  'prime': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46430>,
#  'minister': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46490>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f4c85f464f0>,
#  'scholar': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46550>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x7f4c85f465b0>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46610>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46670>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f4c85f466d0>,
#  'finance': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46730>,
#  'chairman': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46790>,
#  'monetary': <gensim.models.keyedvectors.Vocab at 0x7f4c85f467f0>,
#  'authority': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46850>,
#  'manpower': <gensim.models.keyedvectors.Vocab at 0x7f4c85f468b0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46910>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46970>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x7f4c85f469d0>,
#  'fifty': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46a30>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46a90>,
#  'sri': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46af0>,
#  'lankan': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46b50>,
#  'tamil': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46bb0>,
#  'earned': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46c10>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46c70>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46cd0>,
#  'economics': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46d30>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46d90>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46df0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46e50>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46eb0>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46f10>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46f70>,
#  'administration': <gensim.models.keyedvectors.Vocab at 0x7f4c85f46fd0>,
#  'honoured': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48070>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7f4c85f480d0>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48130>,
#  'outstanding': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48190>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f4c85f481f0>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48250>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f4c85f482b0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48310>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48370>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f4c85f483d0>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48430>,
#  'economy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48490>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f4c85f484f0>,
#  'warming': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48550>,
#  'caps': <gensim.models.keyedvectors.Vocab at 0x7f4c85f485b0>,
#  'navigation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48610>,
#  'routes': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48670>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x7f4c85f486d0>,
#  'relevance': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48730>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48790>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7f4c85f487f0>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48850>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7f4c85f488b0>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48910>,
#  'possibility': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48970>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x7f4c85f489d0>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48a30>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48a90>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48af0>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48b50>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48bb0>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48c10>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48c70>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48cd0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48d30>,
#  'pleasure': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48d90>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48df0>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48e50>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48eb0>,
#  'delimiter': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48f10>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48f70>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7f4c85f48fd0>,
#  'africa': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a070>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a0d0>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a130>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a190>,
#  'excellency': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a1f0>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a250>,
#  'republic': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a2b0>,
#  'zuma': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a310>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a370>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a3d0>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a430>,
#  'generous': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a490>,
#  'hospitality': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a4f0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a550>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a5b0>,
#  'delegation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a610>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a670>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a6d0>,
#  'deeply': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a730>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a790>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a7f0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a850>,
#  'homage': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a8b0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a910>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a970>,
#  'souls': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4a9d0>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4aa30>,
#  'mahatma': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4aa90>,
#  'gandhi': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4aaf0>,
#  'mandela': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ab50>,
#  'centuries': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4abb0>,
#  'nurtured': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ac10>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ac70>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4acd0>,
#  'stood': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ad30>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ad90>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4adf0>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ae50>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4aeb0>,
#  'belongs': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4af10>,
#  'shared': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4af70>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4afd0>,
#  'suffering': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c070>,
#  'struggles': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c0d0>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c130>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c190>,
#  'strategic': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c1f0>,
#  'partnership': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c250>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c2b0>,
#  'discussions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c310>,
#  'reviewed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c370>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c3d0>,
#  'spectrum': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c430>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c490>,
#  'decades': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c4f0>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c550>,
#  'concrete': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c5b0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c610>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c670>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c6d0>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c730>,
#  'percent': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c790>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c7f0>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c850>,
#  'companies': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c8b0>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c910>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c970>,
#  'interests': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4c9d0>,
#  'fourth': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ca30>,
#  'investments': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ca90>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4caf0>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cb50>,
#  'investment': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cbb0>,
#  'ties': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cc10>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cc70>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ccd0>,
#  'minerals': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cd30>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cd90>,
#  'chemicals': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cdf0>,
#  'pharmaceuticals': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ce50>,
#  'manufacturing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ceb0>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cf10>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cf70>,
#  'convinced': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4cfd0>,
#  'industry': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e070>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e0d0>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e130>,
#  'gains': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e190>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e1f0>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e250>,
#  'nations': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e2b0>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e310>,
#  'robust': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e370>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e3d0>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e430>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e490>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e4f0>,
#  'synergies': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e550>,
#  'engagement': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e5b0>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e610>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e670>,
#  'economies': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e6d0>,
#  'demands': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e730>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e790>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e7f0>,
#  'improving': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e850>,
#  'capacities': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e8b0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e910>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e970>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4e9d0>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ea30>,
#  'complement': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ea90>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4eaf0>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4eb50>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ebb0>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ec10>,
#  'expertise': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ec70>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ecd0>,
#  'links': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ed30>,
#  'partner': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ed90>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4edf0>,
#  'defence': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ee50>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4eeb0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ef10>,
#  'sectors': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4ef70>,
#  'witnessing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f4efd0>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50070>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7f4c85f500d0>,
#  'exciting': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50130>,
#  'opportunities': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50190>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7f4c85f501f0>,
#  'jointly': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50250>,
#  'manufacture': <gensim.models.keyedvectors.Vocab at 0x7f4c85f502b0>,
#  'platforms': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50310>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50370>,
#  'respond': <gensim.models.keyedvectors.Vocab at 0x7f4c85f503d0>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50430>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50490>,
#  'closely': <gensim.models.keyedvectors.Vocab at 0x7f4c85f504f0>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50550>,
#  'emerging': <gensim.models.keyedvectors.Vocab at 0x7f4c85f505b0>,
#  'challenges': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50610>,
#  'thanked': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50670>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f4c85f506d0>,
#  'membership': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50730>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50790>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7f4c85f507f0>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50850>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x7f4c85f508b0>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50910>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50970>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x7f4c85f509d0>,
#  'renewable': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50a30>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50a90>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50af0>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50b50>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50bb0>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50c10>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50c70>,
#  'alliance': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50cd0>,
#  'cop': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50d30>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50d90>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50df0>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50e50>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50eb0>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50f10>,
#  'platform': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50f70>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7f4c85f50fd0>,
#  'promoting': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52070>,
#  'thankful': <gensim.models.keyedvectors.Vocab at 0x7f4c85f520d0>,
#  '120': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52130>,
#  'terrorism': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52190>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x7f4c85f521f0>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52250>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7f4c85f522b0>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52310>,
#  'attacks': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52370>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f4c85f523d0>,
#  'foundations': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52430>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52490>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f4c85f524f0>,
#  'vigilant': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52550>,
#  'cooperate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f525b0>,
#  'actively': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52610>,
#  'combat': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52670>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f4c85f526d0>,
#  'waters': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52730>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52790>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7f4c85f527f0>,
#  'frontiers': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52850>,
#  'rim': <gensim.models.keyedvectors.Vocab at 0x7f4c85f528b0>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52910>,
#  'emerged': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52970>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x7f4c85f529d0>,
#  'maritime': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52a30>,
#  'neighbours': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52a90>,
#  'chairmanship': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52af0>,
#  'organization': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52b50>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52bb0>,
#  'priorities': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52c10>,
#  'agenda': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52c70>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52cd0>,
#  'brics': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52d30>,
#  'welcoming': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52d90>,
#  'summit': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52df0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52e50>,
#  'october': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52eb0>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52f10>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52f70>,
#  'ports': <gensim.models.keyedvectors.Vocab at 0x7f4c85f52fd0>,
#  'gujarat': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54070>,
#  'shores': <gensim.models.keyedvectors.Vocab at 0x7f4c85f540d0>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54130>,
#  'vast': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54190>,
#  'oceans': <gensim.models.keyedvectors.Vocab at 0x7f4c85f541f0>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54250>,
#  'resolve': <gensim.models.keyedvectors.Vocab at 0x7f4c85f542b0>,
#  'determination': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54310>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54370>,
#  'excellence': <gensim.models.keyedvectors.Vocab at 0x7f4c85f543d0>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54430>,
#  'exceptional': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54490>,
#  'mozambique': <gensim.models.keyedvectors.Vocab at 0x7f4c85f544f0>,
#  'speech': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54550>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f4c85f545b0>,
#  'nyusi': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54610>,
#  'ladies': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54670>,
#  'gentlemen': <gensim.models.keyedvectors.Vocab at 0x7f4c85f546d0>,
#  'touched': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54730>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54790>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x7f4c85f547f0>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54850>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f4c85f548b0>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54910>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54970>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7f4c85f549d0>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54a30>,
#  'testimony': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54a90>,
#  'traditions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54af0>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54b50>,
#  'commerce': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54bb0>,
#  'suffered': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54c10>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54c70>,
#  'colonial': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54cd0>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54d30>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54d90>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54df0>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54e50>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54eb0>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54f10>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54f70>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7f4c85f54fd0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56070>,
#  'applaud': <gensim.models.keyedvectors.Vocab at 0x7f4c85f560d0>,
#  'fastest': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56130>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56190>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7f4c85f561f0>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56250>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f4c85f562b0>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56310>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56370>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f4c85f563d0>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56430>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56490>,
#  'committed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f564f0>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56550>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f4c85f565b0>,
#  'marked': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56610>,
#  'anniversary': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56670>,
#  'independence': <gensim.models.keyedvectors.Vocab at 0x7f4c85f566d0>,
#  'establishment': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56730>,
#  'diplomatic': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56790>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f4c85f567f0>,
#  'interaction': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56850>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f4c85f568b0>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56910>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56970>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f4c85f569d0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56a30>,
#  'august': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56a90>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56af0>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56b50>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56bb0>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56c10>,
#  'india-africa': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56c70>,
#  'forum': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56cd0>,
#  'aware': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56d30>,
#  '34': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56d90>,
#  'gap': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56df0>,
#  'confident': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56e50>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56eb0>,
#  'excellencies': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56f10>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56f70>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f4c85f56fd0>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58070>,
#  'happiness': <gensim.models.keyedvectors.Vocab at 0x7f4c85f580d0>,
#  'well-being': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58130>,
#  'lasting': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58190>,
#  'peace': <gensim.models.keyedvectors.Vocab at 0x7f4c85f581f0>,
#  'prosperity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58250>,
#  'bonds': <gensim.models.keyedvectors.Vocab at 0x7f4c85f582b0>,
#  'friendship': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58310>,
# ...
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58b50>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58bb0>,
#  'freshness': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58c10>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58c70>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58cd0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58d30>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58d90>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58df0>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58e50>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58eb0>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58f10>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58f70>,
#  'itself': <gensim.models.keyedvectors.Vocab at 0x7f4c85f58fd0>,
#  'enthusiasm': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a070>,
#  'extend': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a0d0>,
#  'farmer': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a130>,
#  'farmers': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a190>,
#  'achieving': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a1f0>,
#  'fronts': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a250>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a2b0>,
#  'heights': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a310>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a370>,
#  'beginning': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a3d0>,
#  'nurture': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a430>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a490>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a4f0>,
#  'keen': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a550>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a5b0>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a610>,
#  'youngsters': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a670>,
#  'zeal': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a6d0>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a730>,
#  'generations': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a790>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a7f0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a850>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a8b0>,
#  'pune': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a910>,
#  'occasion': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a970>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5a9d0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5aa30>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5aa90>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5aaf0>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ab50>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5abb0>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ac10>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ac70>,
#  'satellite': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5acd0>,
#  'launched': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ad30>,
#  'june': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ad90>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5adf0>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ae50>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5aeb0>,
#  'interact': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5af10>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5af70>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5afd0>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c070>,
#  'contributions': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c0d0>,
#  'academic': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c130>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c190>,
#  'courage': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c1f0>,
#  'ambition': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c250>,
#  'dreams': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c2b0>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c310>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c370>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c3d0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c430>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c490>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c4f0>,
#  'achieved': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c550>,
#  'chennai': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c5b0>,
#  'nadu': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c610>,
#  'hearing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c670>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c6d0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c730>,
#  'wishes': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c790>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c7f0>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c850>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c8b0>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c910>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c970>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5c9d0>,
#  'satellites': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ca30>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ca90>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5caf0>,
#  'valuable': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cb50>,
#  'deserve': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cbb0>,
#  'congratulations': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cc10>,
#  'congratulate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cc70>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ccd0>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cd30>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cd90>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cdf0>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ce50>,
#  'records': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ceb0>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cf10>,
#  'joy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cf70>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5cfd0>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e070>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e0d0>,
#  'soil': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e130>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e190>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e1f0>,
#  'owing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e250>,
#  'guarantee': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e2b0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e310>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e370>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e3d0>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e430>,
#  'launching': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e490>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e4f0>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e550>,
#  'educate': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e5b0>,
#  'beti': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e610>,
#  'bachao': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e670>,
#  'padhao': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e6d0>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e730>,
#  'heartfelt': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e790>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e7f0>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e850>,
#  'incidents': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e8b0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e910>,
#  'slogan': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e970>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5e9d0>,
#  '10th': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ea30>,
#  '12th': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ea90>,
#  'classes': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5eaf0>,
#  'daughters': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5eb50>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ebb0>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ec10>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ec70>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ecd0>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ed30>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ed90>,
#  'fighter': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5edf0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ee50>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5eeb0>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ef10>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5ef70>,
#  'flying': <gensim.models.keyedvectors.Vocab at 0x7f4c85f5efd0>,
#  'officer': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60070>,
#  'accomplished': <gensim.models.keyedvectors.Vocab at 0x7f4c85f600d0>,
#  'madhya': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60130>,
#  'pradesh': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60190>,
#  'bihar': <gensim.models.keyedvectors.Vocab at 0x7f4c85f601f0>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60250>,
#  'hail': <gensim.models.keyedvectors.Vocab at 0x7f4c85f602b0>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60310>,
#  'cities': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60370>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f4c85f603d0>,
#  'respective': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60430>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60490>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f4c85f604f0>,
#  'towns': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60550>,
#  'heartiest': <gensim.models.keyedvectors.Vocab at 0x7f4c85f605b0>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60610>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60670>,
#  '21st': <gensim.models.keyedvectors.Vocab at 0x7f4c85f606d0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60730>,
#  'organised': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60790>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x7f4c85f607f0>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60850>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f4c85f608b0>,
#  'yoga': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60910>,
#  'witness': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60970>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7f4c85f609d0>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60a30>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60a90>,
#  'linked': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60af0>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60b50>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60bb0>,
#  'bond': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60c10>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60c70>,
#  'celebrated': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60cd0>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60d30>,
#  'lakh': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60d90>,
#  'forms': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60df0>,
#  'atmosphere': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60e50>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60eb0>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60f10>,
#  'chandigarh': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60f70>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x7f4c85f60fd0>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62070>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x7f4c85f620d0>,
#  'alike': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62130>,
#  'issued': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62190>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f4c85f621f0>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62250>,
#  'organisation': <gensim.models.keyedvectors.Vocab at 0x7f4c85f622b0>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62310>,
#  'quarters': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62370>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x7f4c85f623d0>,
#  'located': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62430>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62490>,
#  'organized': <gensim.models.keyedvectors.Vocab at 0x7f4c85f624f0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62550>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7f4c85f625b0>,
#  'pictures': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62610>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62670>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7f4c85f626d0>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62730>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62790>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f4c85f627f0>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62850>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7f4c85f628b0>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62910>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62970>,
#  'carried': <gensim.models.keyedvectors.Vocab at 0x7f4c85f629d0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62a30>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62a90>,
#  'pleasant': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62af0>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62b50>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62bb0>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62c10>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62c70>,
#  'mobile': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62cd0>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62d30>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62d90>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62df0>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62e50>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62eb0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62f10>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62f70>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f4c85f62fd0>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64070>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7f4c85f640d0>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64130>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64190>,
#  'played': <gensim.models.keyedvectors.Vocab at 0x7f4c85f641f0>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64250>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f4c85f642b0>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64310>,
#  'ji': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64370>,
#  'suggestion': <gensim.models.keyedvectors.Vocab at 0x7f4c85f643d0>,
#  'observe': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64430>,
#  'carefully': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64490>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7f4c85f644f0>,
#  't.v': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64550>,
#  'channels': <gensim.models.keyedvectors.Vocab at 0x7f4c85f645b0>,
#  'contribution': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64610>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64670>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7f4c85f646d0>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64730>,
#  'dedicated': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64790>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x7f4c85f647f0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f4c85f64850>,
#  ...}
