# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
alpha = PIL.Image.open(r"C:/Users/naman/Desktop/Python training/Lecture_04/A.png")

# %%
a = np.array(alpha)

# %%
a.shape
# Out:
# (1686, 5000, 4)

# %%
d = a[::12,::12]

# %%
d.shape
# Out:
# (141, 417, 4)

# %%
pan = PIL.Image.open(r"C:/Users/naman/Desktop/Python training/Lecture_01/panda.jpg")

# %%
b = np.array(pan)

# %%
plt.imshow(d[:,:,3], cmap="gray")

# %%
b.shape
# Out:
# (720, 1280, 3)

# %%
PIL.ImageChops.offset?
# Out:
# Signature: PIL.ImageChops.offset(image, xoffset, yoffset=None)
# Docstring:
# Returns a copy of the image where data has been offset by the given
# distances. Data wraps around the edges. If **yoffset** is omitted, it
# is assumed to be equal to **xoffset**.
#
# :param xoffset: The horizontal distance.
# :param yoffset: The vertical distance.  If omitted, both
#     distances are set to the same value.
# :rtype: :py:class:`~PIL.Image.Image`
# File:      d:\anaconda\lib\site-packages\pil\imagechops.py
# Type:      function

# %%
cut =  b[:d.shape[0],-d.shape[1]:]

# %%
plt.imshow(cut)

# %%
for row in range(d.shape[0]):
    for col in range(d.shape[1]):
        if d[row, col, 3] > 100:
            cut[row, col] = d[row, col, :3]

# %%
plt.imshow(b)

# %%
img = PIL.Image.fromarray(b)

# %%
s = open("My.jpg", "wb")

img.save(s)

# %%
#to create moving over lay use ofset in cut

# %%
cut = b[:d.shape[0], :d.shape[1]]

# %%
for row in range(d.shape[0]):
    for col in range(d.shape[1]):
        if d[row, col, 3] > 100:
            cut[row, col] = d[row, col, :3]

# %%
plt.imshow(b)
