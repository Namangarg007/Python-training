# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
x = np.linspace(0, 2*np.pi, 20)

# %%
y = np.sin(x)

# %%
plt.plot(y)

# %%
plt.scatter(x, y)

# %%
x = np.linspace(-100, 100, 10)

# %%
plt.plot(x)

# %%
plt.plot(x, x**2)
plt.plot(x, x**3)

# %%
x = np.linspace(0, 2*np.pi**10, 100)

# %%
f = np.linspace(0, 2*np.pi**5, 100)

# %%
a = 5 * np.sin(x)
b = 5 * np.cos(x)

# %%
plt.plot(a, b)

# %%
y = f * np.sin(x)
z = f * np.cos(x)

# %%
plt.plot(z, y)
