# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs

# %%
X, y= make_blobs(centers=5, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(4)

# %%
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
model.labels_
# Out:
# array([1, 2, 0, 2, 3, 1, 2, 2, 2, 0, 0, 1, 2, 0, 2, 3, 2, 2, 1, 3, 3, 2,
#        0, 1, 3, 3, 2, 2, 2, 2, 1, 3, 2, 2, 2, 3, 0, 0, 0, 2, 1, 2, 2, 2,
#        3, 0, 0, 1, 3, 2, 2, 2, 2, 1, 2, 3, 2, 2, 0, 0, 2, 0, 3, 1, 3, 1,
#        2, 2, 1, 2, 3, 1, 1, 1, 2, 3, 2, 3, 2, 1, 2, 1, 3, 2, 3, 0, 3, 0,
#        0, 0, 3, 0, 1, 2, 1, 0, 1, 0, 2, 2], dtype=int32)

# %%
plt.scatter(X[:, 0], X[:, 1], c=model.labels_)

for center in model.cluster_centers_:
    plt.scatter(center[0], center[1], s=100)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
